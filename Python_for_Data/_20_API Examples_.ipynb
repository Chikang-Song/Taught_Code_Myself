# %% [markdown]
# # Hands-on Lab: API Examples
# ## Random User and Fruityvice API Examples

# %% [markdown]
# ## Example 1: RandomUser API
# 우리가 이 노트북에서 사용할 애플리케이션 중 하나는 Random User Generator입니다. RandomUser는 개발자들이 테스트 목적으로 자리 표시자(user placeholder)로 사용할 수 있도록 무작위로 생성된 사용자 데이터를 제공하는 오픈 소스 무료 API입니다. 이 도구는 Lorem Ipsum과 비슷하지만, 텍스트 대신 사람에 대한 정보를 자리 표시자로 사용한다는 점이 다릅니다.
#
# 이 API는 여러 사용자를 한 번에 반환할 수 있으며, 생성되는 사용자 정보로 성별, 이메일, 이미지, 사용자 이름, 주소, 직함, 이름(이름과 성) 등을 지정할 수 있습니다. RandomUser에 대한 추가 정보는 여기에서 확인할 수 있습니다.
#
#
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Requirement already satisfied: randomuser in c:\users\user\anaconda3\lib\site-packages (1.6)

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)
some_list
# Out:
# [<randomuser.RandomUser at 0x1a4f12c0a60>,
#  <randomuser.RandomUser at 0x1a4f12c01c0>,
#  <randomuser.RandomUser at 0x1a4f12c05b0>,
#  <randomuser.RandomUser at 0x1a4f12c07f0>,
#  <randomuser.RandomUser at 0x1a4f12c0700>,
#  <randomuser.RandomUser at 0x1a4f12c0580>,
#  <randomuser.RandomUser at 0x1a4f12c0550>,
#  <randomuser.RandomUser at 0x1a4f12c0640>,
#  <randomuser.RandomUser at 0x1a4f12c0670>,
#  <randomuser.RandomUser at 0x1a4f12c0910>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function

# %%
for user in some_list:
    print(f"{user.get_full_name()} {user.get_email()}")
# Out:
# Alex Jensen alex.jensen@example.com
# Owen Taylor owen.taylor@example.com
# Mahmoud Hinrichsen mahmoud.hinrichsen@example.com
# Cecilia Lambert cecilia.lambert@example.com
# Holly Harris holly.harris@example.com
# Carlos Bergman carlos.bergman@example.com
# یلدا كامياران yld.kmyrn@example.com
# Romeé Erdem romee.erdem@example.com
# Marius Larsen marius.larsen@example.com
# Vedat Günday vedat.gunday@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 10 users.

# %%
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/96.jpg
# https://randomuser.me/api/portraits/men/64.jpg
# https://randomuser.me/api/portraits/men/46.jpg
# https://randomuser.me/api/portraits/women/74.jpg
# https://randomuser.me/api/portraits/women/28.jpg
# https://randomuser.me/api/portraits/men/52.jpg
# https://randomuser.me/api/portraits/women/36.jpg
# https://randomuser.me/api/portraits/women/19.jpg
# https://randomuser.me/api/portraits/men/24.jpg
# https://randomuser.me/api/portraits/men/75.jpg

# %% [markdown]
# 사용자에 대한 정보를 표 형태로 생성하려면, 원하는 모든 파라미터를 포함하는 함수를 작성할 수 있습니다. 예를 들어, 이름(name), 성별(gender), 도시(city) 등의 정보를 포함할 수 있습니다. 이 파라미터들은 수행할 테스트의 요구 사항에 따라 달라집니다.
#
# 우리는 이 노트북의 앞부분에 나열된 **Get Methods**를 호출합니다. 그런 다음, 사용자 데이터를 담은 **pandas 데이터프레임(pandas dataframe)**을 반환합니다.

# %%
def get_users():
    users = []

    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),
                      "City":user.get_state(), "Email":user.get_email(),
                      "DOB":user.get_dob(), "Picture":user.get_picture()
                     })
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                  Name  Gender                  City  \
# 0    Corinna Flemming  female                Hessen
# 1  Enrique Cunningham    male       South Australia
# 2       Roberto Ortiz    male  Comunidad Valenciana
# 3     Alvarino Duarte    male                  Pará
# 4          Maxime Chu    male           Nova Scotia
# 5         Henry Selle    male               Hamburg
# 6       Chiara Moulin  female                  Aube
# 7        Earl Ramirez    male                Kansas
# 8  Jennifer Carpenter  female                  Avon
# 9         مهدي سالاری    male                گلستان
#
#                             Email                       DOB  \
# 0    corinna.flemming@example.com  1971-11-25T21:34:12.957Z
# 1  enrique.cunningham@example.com  1983-12-18T07:22:11.048Z
# 2       roberto.ortiz@example.com  1982-03-28T01:43:27.501Z
# 3     alvarino.duarte@example.com  1957-08-12T12:56:38.011Z
# 4          maxime.chu@example.com  1982-04-28T18:59:59.330Z
# 5         henry.selle@example.com  1966-09-29T14:30:37.767Z
# 6       chiara.moulin@example.com  1975-06-16T02:02:03.505Z
# 7        earl.ramirez@example.com  1967-03-22T12:04:54.219Z
# 8  jennifer.carpenter@example.com  1973-11-13T04:22:17.731Z
# 9           mhdy.slry@example.com  1959-08-22T23:26:59.350Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/79.jpg
# 1     https://randomuser.me/api/portraits/men/1.jpg
# 2    https://randomuser.me/api/portraits/men/34.jpg
# 3    https://randomuser.me/api/portraits/men/10.jpg
# 4    https://randomuser.me/api/portraits/men/40.jpg
# 5    https://randomuser.me/api/portraits/men/80.jpg
# 6  https://randomuser.me/api/portraits/women/34.jpg
# 7    https://randomuser.me/api/portraits/men/91.jpg
# 8  https://randomuser.me/api/portraits/women/37.jpg
# 9    https://randomuser.me/api/portraits/men/51.jpg

# %%
df1 = get_users()

# %%
df1
# Out:
#                   Name  Gender                    City  \
# 0         Nikolas Kern    male                  Berlin
# 1         Milja Savela  female             Päijät-Häme
# 2    Hans-Detlef Hundt    male  Mecklenburg-Vorpommern
# 3         Anne Chapman  female                   Maine
# 4          Bill Torres    male                  Oregon
# 5       اميرمحمد نجاتی    male                 کردستان
# 6       Audrey Holland  female                 Indiana
# 7  Zine-Eddine Meulman    male               Friesland
# 8           مریم قاسمی  female                    فارس
# 9   Clifton Washington    male                Tasmania
#
#                              Email                       DOB  \
# 0         nikolas.kern@example.com  1976-09-29T17:43:53.336Z
# 1         milja.savela@example.com  1954-03-23T03:50:05.739Z
# 2    hans-detlef.hundt@example.com  1962-10-27T05:41:00.769Z
# 3         anne.chapman@example.com  1977-06-19T21:26:25.775Z
# 4          bill.torres@example.com  1957-08-30T08:15:05.895Z
# 5         myrmhmd.njty@example.com  1957-06-05T09:16:42.089Z
# 6       audrey.holland@example.com  1946-09-18T05:51:07.980Z
# 7  zine-eddine.meulman@example.com  1964-06-05T01:55:18.012Z
# 8            mrym.qsmy@example.com  1992-12-10T03:23:19.261Z
# 9   clifton.washington@example.com  1989-03-30T23:59:11.582Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/51.jpg
# 1  https://randomuser.me/api/portraits/women/84.jpg
# 2     https://randomuser.me/api/portraits/men/2.jpg
# 3  https://randomuser.me/api/portraits/women/12.jpg
# 4    https://randomuser.me/api/portraits/men/63.jpg
# 5    https://randomuser.me/api/portraits/men/97.jpg
# 6  https://randomuser.me/api/portraits/women/45.jpg
# 7    https://randomuser.me/api/portraits/men/99.jpg
# 8  https://randomuser.me/api/portraits/women/76.jpg
# 9    https://randomuser.me/api/portraits/men/98.jpg

# %% [markdown]
# 이제 우리는 테스트 담당자가 필요로 하는 모든 테스트 목적에 사용할 수 있는 **pandas 데이터프레임**을 갖게 되었습니다.

# %% [markdown]
# ## Example 2: Fruityvice API
#
# 또 다른, 더 일반적인 API 사용 방법은 **`requests` 라이브러리**를 사용하는 것입니다. 다음 실습인 **Requests and HTTP**에서는 요청(requests)에 대한 더 자세한 정보를 다룰 것입니다.
#
# 우리는 먼저 필요한 모든 라이브러리를 가져오는(import) 작업을 시작하겠습니다.

# %%
import requests
import json

# %% [markdown]
# 우리는 **`requests.get("url")`** 함수를 사용하여 [Fruityvice](https://www.fruityvice.com) API 데이터를 가져올 것입니다.
# 해당 데이터는 **JSON 형식**으로 제공됩니다.

# %%
data = requests.get("https://web.archive.org/web/20240929211114/https://fruityvice.com/api/fruit/all")

# %% [markdown]
#  **`json.loads()`** 함수를 사용하여 결과 데이터를 가져올 것입니다.

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#                                            nutritions
# 0   {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2   {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3   {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4   {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5   {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6   {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7   {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8   {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9   {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10  {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11  {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13  {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14  {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15  {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 17  {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'ca...
# 18  {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 20  {'calories': 60, 'fat': 0.38, 'sugar': 13.7, '...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 22  {'calories': 52, 'fat': 0.4, 'sugar': 10.3, 'c...
# 23  {'calories': 68, 'fat': 1.0, 'sugar': 9.0, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 25  {'calories': 34, 'fat': 0.0, 'sugar': 8.0, 'ca...
# 26  {'calories': 45, 'fat': 0.4, 'sugar': 9.1, 'ca...
# 27  {'calories': 36, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 28  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...
# 29  {'calories': 83, 'fat': 1.2, 'sugar': 13.7, 'c...
# 30  {'calories': 60, 'fat': 1.5, 'sugar': 8.0, 'ca...
# 31  {'calories': 69, 'fat': 0.16, 'sugar': 16.0, '...
# 32  {'calories': 43, 'fat': 0.39, 'sugar': 8.1, 'c...
# 33  {'calories': 44, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 34  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...
# 35  {'calories': 61, 'fat': 0.5, 'sugar': 8.9, 'ca...
# 36  {'calories': 46, 'fat': 0.1, 'sugar': 4.0, 'ca...
# 37  {'calories': 50, 'fat': 0.3, 'sugar': 8.0, 'ca...
# 38  {'calories': 39, 'fat': 0.25, 'sugar': 8.4, 'c...
# 39  {'calories': 95, 'fat': 0.0, 'sugar': 19.1, 'c...
# 40  {'calories': 44, 'fat': 1.26, 'sugar': 0.5, 'c...
# 41  {'calories': 628, 'fat': 61.0, 'sugar': 4.3, '...
# 42  {'calories': 37, 'fat': 0.0, 'sugar': 8.5, 'ca...
# 43  {'calories': 73, 'fat': 0.58, 'sugar': 16.11, ...
# 44  {'calories': 25, 'fat': 0.3, 'sugar': 3.3, 'ca...
# 45  {'calories': 70, 'fat': 0.2, 'sugar': 13.0, 'c...
# 46  {'calories': 39, 'fat': 0.3, 'sugar': 4.4, 'ca...
# 47  {'calories': 92, 'fat': 0.29, 'sugar': 3.4, 'c...
# 48  {'calories': 47, 'fat': 0.3, 'sugar': 8.1, 'ca...

# %% [markdown]
# 결과는 중첩된 **JSON 형식**으로 제공됩니다.
# 특히 **'nutrition'** 열에는 여러 하위 열(subcolumns)이 포함되어 있으므로, 데이터를 '평탄화(flatten)' 또는 '정규화(normalize)'해야 합니다.

# %%
df2 = pd.json_normalize(results)
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   34            0.00              8.00
# 26                   45            0.40              9.10
# 27                   36            0.40              3.00
# 28                   25            0.10              1.70
# 29                   83            1.20             13.70
# 30                   60            1.50              8.00
# 31                   69            0.16             16.00
# 32                   43            0.39              8.10
# 33                   44            0.40              3.00
# 34                  160           14.66              0.66
# 35                   61            0.50              8.90
# 36                   46            0.10              4.00
# 37                   50            0.30              8.00
# 38                   39            0.25              8.40
# 39                   95            0.00             19.10
# 40                   44            1.26              0.50
# 41                  628           61.00              4.30
# 42                   37            0.00              8.50
# 43                   73            0.58             16.11
# 44                   25            0.30              3.30
# 45                   70            0.20             13.00
# 46                   39            0.30              4.40
# 47                   92            0.29              3.40
# 48                   47            0.30              8.10
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                      8.00                0.00
# 26                      8.30                0.00
# 27                      7.00                1.00
# 28                      8.40                0.30
# 29                     18.70                1.70
# 30                      9.00                9.00
# 31                     18.10                0.72
# 32                      9.80                1.44
# 33                      8.00                0.60
# 34                      8.53                2.00
# 35                     14.60                1.14
# 36                     12.20                0.40
# 37                     12.00                1.00
# 38                      9.50                0.90
# 39                     23.20                1.72
# 40                      7.56                1.78
# 41                     17.00               15.00
# 42                      9.67                0.82
# 43                     17.91                0.41
# 44                      4.60                1.10
# 45                     19.00                0.60
# 46                      5.80                0.50
# 47                     19.10                1.50
# 48                      9.60                1.20

# %% [markdown]
# **`df2`**
# 이 데이터프레임에서 일부 정보를 추출할 수 있는지 확인해 봅시다.
# 예를 들어, 체리(cherry)의 **과(family)**와 **속(genus)** 정보를 알아야 할 수도 있습니다.

# %%
df2.columns
# Out:
# Index(['name', 'id', 'family', 'order', 'genus', 'nutritions.calories',
#        'nutritions.fat', 'nutritions.sugar', 'nutritions.carbohydrates',
#        'nutritions.protein'],
#       dtype='object')

# %%
cherry = df2.loc[df2['name'] == 'Cherry']
(cherry.iloc[0]['family']), (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
#
# 이 연습에서 **바나나**에 포함된 **칼로리 수**를 찾아보세요.

# %%
banana = df2[df2['name'].str.lower() == 'banana']

# %%
banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# ## Exercise 3
#
# 이 [페이지](https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/)에는 연습에 사용할 수 있는 무료 공개 API 목록이 나와 있습니다. 이제 다음 예제를 다뤄봅시다.
#
# ---
#
# ### 🃏 **Official Joke API**
# 이 API는 데이터베이스에서 무작위로 농담(jokes)을 반환합니다.
# 아래 URL을 사용하면 **무작위로 10개의 농담**을 가져올 수 있습니다.
#
# 🔗 **URL:**
# `https://official-joke-api.appspot.com/jokes/ten`
#
# ---
#
# **연습 문제:**
# 1️⃣ **`requests.get("url")`** 함수를 사용하여 이 URL에서 데이터를 가져오세요.

# %%
import requests

data = requests.get('https://official-joke-api.appspot.com/jokes/ten')

# %% [markdown]
# 2️⃣ **`json.loads()`** 함수를 사용하여 결과 데이터를 가져오세요.

# %%
results = json.loads(data.text)

# %% [markdown]
# 3️⃣ JSON 데이터를 **pandas 데이터프레임**으로 변환하세요.
# 그런 다음, **`type`** 열과 **`id`** 열을 제거하세요.

# %%
df = pd.DataFrame(results)
df.drop(columns = ['id','type'], inplace = True)
# Out:
#                                                setup  \
# 0  Why do fathers take an extra pair of socks whe...
# 1  I got hit in the head by a soda can, but it di...
# 2                                Can February march?
# 3               What do you call two barracuda fish?
# 4       Which side of the chicken has more feathers?
# 5           Why did Dracula lie in the wrong coffin?
# 6                 Do I enjoy making courthouse puns?
# 7                         Why are skeletons so calm?
# 8                   What do you call a careful wolf?
# 9                 Have you heard of the band 1023MB?
#
#                                 punchline
# 0         In case they get a hole in one!
# 1                    It was a soft drink.
# 2                      No, but April may.
# 3                            A Pairacuda!
# 4                            The outside.
# 5                He made a grave mistake.
# 6                                  Guilty
# 7  Because nothing gets under their skin.
# 8                             Aware wolf.
# 9             They haven't got a gig yet.
